# %% [markdown]
# # Introduction

# %% [markdown]
# ---
# **Random Forest**
#
# - Mô hình *Rừng ngẫu nhiên* (Random Forest) là thuật toán học máy theo kiểu tổ hợp.
# - Mô hình xây nhiều cây quyết định và kết hợp kết quả của chúng để ra kết quả cuối cùng.
# - Bài toán phân loại: Lấy kết quả theo đa số.
# - Bài toán hồi quy: Lấy kết quả trung bình.
#
# ---

# %% [markdown]
# ---
# **Emotion Dataset**
#
# - Bộ dữ liệu ghi lại các tweet được phân loại theo cảm xúc.
# - Phân loại theo 6 cảm xúc.
#
# ---

# %% [markdown]
# ---
# **Model**
#
# - Mục tiêu bài toán: Phân loại cảm xúc theo tin tweet.
# - Dữ liệu: Không cần chuẩn hoá.
# - Công nghệ: Tensorflow hay cụ thể là TF-DF.
# - Chương trình được viết và chạy trên google colab, nếu muốn chạy trên các công cụ khác yêu cầu *download* list thư viện dưới đây
#
# ---

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.1.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.9
# aiosignal                          1.3.1
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             4.2.2
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2024.12.2.0.35.34
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# attrs                              24.2.0
# audioread                          3.0.1
# autograd                           1.7.0
# babel                              2.16.0
# backcall                           0.2.0
# beautifulsoup4                     4.12.3
# bigframes                          1.27.0
# bigquery-magics                    0.4.0
# bleach                             6.2.0
# blinker                            1.9.0
# blis                               0.7.11
# blosc2                             2.7.1
# bokeh                              3.6.2
# Bottleneck                         1.4.2
# bqplot                             0.12.43
# branca                             0.8.0
# CacheControl                       0.14.1
# cachetools                         5.5.0
# catalogue                          2.0.10
# certifi                            2024.8.30
# cffi                               1.17.1
# chardet                            5.2.0
# charset-normalizer                 3.4.0
# chex                               0.1.87
# clarabel                           0.9.0
# click                              8.1.7
# cloudpathlib                       0.20.0
# cloudpickle                        3.1.0
# cmake                              3.30.5
# cmdstanpy                          1.2.4
# colabtools                         0.0.1
# colorcet                           3.1.0
# colorlover                         0.3.0
# colour                             0.1.5
# community                          1.0.0b1
# confection                         0.1.5
# cons                               0.4.6
# contourpy                          1.3.1
# cryptography                       43.0.3
# cuda-python                        12.2.1
# cudf-cu12                          24.10.1
# cufflinks                          0.17.3
# cupy-cuda12x                       12.2.0
# cvxopt                             1.3.2
# cvxpy                              1.5.4
# cycler                             0.12.1
# cymem                              2.0.10
# Cython                             3.0.11
# dask                               2024.10.0
# datascience                        0.17.6
# db-dtypes                          1.3.1
# dbus-python                        1.2.18
# debugpy                            1.8.0
# decorator                          4.4.2
# defusedxml                         0.7.1
# Deprecated                         1.2.15
# diffusers                          0.31.0
# distro                             1.9.0
# dlib                               19.24.2
# dm-tree                            0.1.8
# docker-pycreds                     0.4.0
# docstring_parser                   0.16
# docutils                           0.21.2
# dopamine_rl                        4.0.9
# duckdb                             1.1.3
# earthengine-api                    1.2.0
# easydict                           1.13
# ecos                               2.0.14
# editdistance                       0.8.1
# eerepr                             0.0.4
# einops                             0.8.0
# en-core-web-sm                     3.7.1
# entrypoints                        0.4
# et_xmlfile                         2.0.0
# etils                              1.11.0
# etuples                            0.3.9
# eval_type_backport                 0.2.0
# exceptiongroup                     1.2.2
# fastai                             2.7.18
# fastcore                           1.7.22
# fastdownload                       0.0.7
# fastjsonschema                     2.21.1
# fastprogress                       1.0.3
# fastrlock                          0.8.2
# filelock                           3.16.1
# firebase-admin                     6.5.0
# Flask                              3.0.3
# flatbuffers                        24.3.25
# flax                               0.8.5
# folium                             0.18.0
# fonttools                          4.55.1
# frozendict                         2.4.6
# frozenlist                         1.5.0
# fsspec                             2024.10.0
# future                             1.0.0
# gast                               0.6.0
# gcsfs                              2024.10.0
# GDAL                               3.6.4
# gdown                              5.2.0
# geemap                             0.35.1
# gensim                             4.3.3
# geocoder                           1.38.1
# geographiclib                      2.0
# geopandas                          1.0.1
# geopy                              2.4.1
# gin-config                         0.5.0
# gitdb                              4.0.11
# GitPython                          3.1.43
# glob2                              0.7
# google                             2.0.3
# google-ai-generativelanguage       0.6.10
# google-api-core                    2.19.2
# google-api-python-client           2.151.0
# google-auth                        2.27.0
# google-auth-httplib2               0.2.0
# google-auth-oauthlib               1.2.1
# google-cloud-aiplatform            1.73.0
# google-cloud-bigquery              3.25.0
# google-cloud-bigquery-connection   1.16.1
# google-cloud-bigquery-storage      2.27.0
# google-cloud-bigtable              2.27.0
# google-cloud-core                  2.4.1
# google-cloud-datastore             2.20.1
# google-cloud-firestore             2.19.0
# google-cloud-functions             1.18.1
# google-cloud-iam                   2.16.1
# google-cloud-language              2.15.1
# google-cloud-pubsub                2.27.1
# google-cloud-resource-manager      1.13.1
# google-cloud-storage               2.8.0
# google-cloud-translate             3.17.0
# google-colab                       1.0.0
# google-crc32c                      1.6.0
# google-generativeai                0.8.3
# google-pasta                       0.2.0
# google-resumable-media             2.7.2
# googleapis-common-protos           1.66.0
# googledrivedownloader              0.4
# graphviz                           0.20.3
# greenlet                           3.1.1
# grpc-google-iam-v1                 0.13.1
# grpcio                             1.68.1
# grpcio-status                      1.62.3
# gspread                            6.0.2
# gspread-dataframe                  3.3.1
# gym                                0.25.2
# gym-notices                        0.0.8
# h11                                0.14.0
# h5netcdf                           1.4.1
# h5py                               3.12.1
# holidays                           0.62
# holoviews                          1.20.0
# html5lib                           1.1
# httpcore                           1.0.7
# httpimport                         1.4.0
# httplib2                           0.22.0
# httpx                              0.28.0
# huggingface-hub                    0.26.3
# humanize                           4.11.0
# hyperopt                           0.2.7
# ibis-framework                     9.2.0
# idna                               3.10
# imageio                            2.36.1
# imageio-ffmpeg                     0.5.1
# imagesize                          1.4.1
# imbalanced-learn                   0.12.4
# imgaug                             0.4.0
# immutabledict                      4.2.1
# importlib_metadata                 8.5.0
# importlib_resources                6.4.5
# imutils                            0.5.4
# inflect                            7.4.0
# iniconfig                          2.0.0
# intel-cmplr-lib-ur                 2025.0.3
# intel-openmp                       2025.0.3
# ipyevents                          2.0.2
# ipyfilechooser                     0.6.0
# ipykernel                          5.5.6
# ipyleaflet                         0.19.2
# ipyparallel                        8.8.0
# ipython                            7.34.0
# ipython-genutils                   0.2.0
# ipython-sql                        0.5.0
# ipytree                            0.2.2
# ipywidgets                         7.7.1
# itsdangerous                       2.2.0
# jax                                0.4.33
# jax-cuda12-pjrt                    0.4.33
# jax-cuda12-plugin                  0.4.33
# jaxlib                             0.4.33
# jeepney                            0.7.1
# jellyfish                          1.1.2
# jieba                              0.42.1
# Jinja2                             3.1.4
# jiter                              0.8.0
# joblib                             1.4.2
# jsonpatch                          1.33
# jsonpickle                         4.0.0
# jsonpointer                        3.0.0
# jsonschema                         4.23.0
# jsonschema-specifications          2024.10.1
# jupyter-client                     6.1.12
# jupyter-console                    6.1.0
# jupyter_core                       5.7.2
# jupyter-leaflet                    0.19.2
# jupyter-server                     1.24.0
# jupyterlab_pygments                0.3.0
# jupyterlab_widgets                 3.0.13
# kaggle                             1.6.17
# kagglehub                          0.3.4
# keras                              3.5.0
# keyring                            23.5.0
# kiwisolver                         1.4.7
# langchain                          0.3.9
# langchain-core                     0.3.21
# langchain-text-splitters           0.3.2
# langcodes                          3.5.0
# langsmith                          0.1.147
# language_data                      1.3.0
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# lazy_loader                        0.4
# libclang                           18.1.1
# libcudf-cu12                       24.10.1
# librosa                            0.10.2.post1
# lightgbm                           4.5.0
# linkify-it-py                      2.0.3
# llvmlite                           0.43.0
# locket                             1.0.0
# logical-unification                0.4.6
# lxml                               5.3.0
# marisa-trie                        1.2.1
# Markdown                           3.7
# markdown-it-py                     3.0.0
# MarkupSafe                         3.0.2
# matplotlib                         3.8.0
# matplotlib-inline                  0.1.7
# matplotlib-venn                    1.1.1
# mdit-py-plugins                    0.4.2
# mdurl                              0.1.2
# miniKanren                         1.0.3
# missingno                          0.5.2
# mistune                            3.0.2
# mizani                             0.13.0
# mkl                                2025.0.1
# ml-dtypes                          0.4.1
# mlxtend                            0.23.3
# more-itertools                     10.5.0
# moviepy                            1.0.3
# mpmath                             1.3.0
# msgpack                            1.1.0
# multidict                          6.1.0
# multipledispatch                   1.0.0
# multitasking                       0.0.11
# murmurhash                         1.0.11
# music21                            9.3.0
# namex                              0.0.8
# natsort                            8.4.0
# nbclassic                          1.1.0
# nbclient                           0.10.1
# nbconvert                          7.16.4
# nbformat                           5.10.4
# ndindex                            1.9.2
# nest-asyncio                       1.6.0
# networkx                           3.4.2
# nibabel                            5.3.2
# nltk                               3.9.1
# notebook                           6.5.5
# notebook_shim                      0.2.4
# numba                              0.60.0
# numexpr                            2.10.2
# numpy                              1.26.4
# nvidia-cublas-cu12                 12.6.4.1
# nvidia-cuda-cupti-cu12             12.6.80
# nvidia-cuda-nvcc-cu12              12.6.85
# nvidia-cuda-runtime-cu12           12.6.77
# nvidia-cudnn-cu12                  9.6.0.74
# nvidia-cufft-cu12                  11.3.0.4
# nvidia-curand-cu12                 10.3.7.77
# nvidia-cusolver-cu12               11.7.1.2
# nvidia-cusparse-cu12               12.5.4.2
# nvidia-nccl-cu12                   2.23.4
# nvidia-nvjitlink-cu12              12.6.85
# nvtx                               0.2.10
# nx-cugraph-cu12                    24.10.0
# oauth2client                       4.1.3
# oauthlib                           3.2.2
# openai                             1.54.5
# opencv-contrib-python              4.10.0.84
# opencv-python                      4.10.0.84
# opencv-python-headless             4.10.0.84
# openpyxl                           3.1.5
# opentelemetry-api                  1.28.2
# opentelemetry-sdk                  1.28.2
# opentelemetry-semantic-conventions 0.49b2
# opt_einsum                         3.4.0
# optax                              0.2.4
# optree                             0.13.1
# orbax-checkpoint                   0.6.4
# orjson                             3.10.12
# osqp                               0.6.7.post3
# packaging                          24.2
# pandas                             2.2.2
# pandas-datareader                  0.10.0
# pandas-gbq                         0.24.0
# pandas-stubs                       2.2.2.240909
# pandocfilters                      1.5.1
# panel                              1.5.4
# param                              2.1.1
# parso                              0.8.4
# parsy                              2.1
# partd                              1.4.2
# pathlib                            1.0.1
# patsy                              1.0.1
# peewee                             3.17.8
# peft                               0.13.2
# pexpect                            4.9.0
# pickleshare                        0.7.5
# pillow                             11.0.0
# pip                                24.1.2
# platformdirs                       4.3.6
# plotly                             5.24.1
# plotnine                           0.14.3
# pluggy                             1.5.0
# ply                                3.11
# polars                             1.9.0
# pooch                              1.8.2
# portpicker                         1.5.2
# preshed                            3.0.9
# prettytable                        3.12.0
# proglog                            0.1.10
# progressbar2                       4.5.0
# prometheus_client                  0.21.1
# promise                            2.3
# prompt_toolkit                     3.0.48
# propcache                          0.2.1
# prophet                            1.1.6
# proto-plus                         1.25.0
# protobuf                           4.25.5
# psutil                             5.9.5
# psycopg2                           2.9.10
# ptyprocess                         0.7.0
# py-cpuinfo                         9.0.0
# py4j                               0.10.9.7
# pyarrow                            17.0.0
# pyarrow-hotfix                     0.6
# pyasn1                             0.6.1
# pyasn1_modules                     0.4.1
# pycocotools                        2.0.8
# pycparser                          2.22
# pydantic                           2.10.3
# pydantic_core                      2.27.1
# pydata-google-auth                 1.9.0
# pydot                              3.0.3
# pydotplus                          2.0.2
# PyDrive                            1.3.1
# PyDrive2                           1.21.3
# pyerfa                             2.0.1.5
# pygame                             2.6.1
# pygit2                             1.16.0
# Pygments                           2.18.0
# PyGObject                          3.42.1
# PyJWT                              2.10.1
# pylibcudf-cu12                     24.10.1
# pylibcugraph-cu12                  24.10.0
# pylibraft-cu12                     24.10.0
# pymc                               5.18.2
# pymystem3                          0.2.0
# pynvjitlink-cu12                   0.4.0
# pyogrio                            0.10.0
# Pyomo                              6.8.2
# PyOpenGL                           3.1.7
# pyOpenSSL                          24.2.1
# pyparsing                          3.2.0
# pyperclip                          1.9.0
# pyproj                             3.7.0
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.3
# pytensor                           2.26.4
# pytest                             8.3.4
# python-apt                         0.0.0
# python-box                         7.2.0
# python-dateutil                    2.8.2
# python-louvain                     0.16
# python-slugify                     8.0.4
# python-utils                       3.9.1
# pytz                               2024.2
# pyviz_comms                        3.0.3
# PyYAML                             6.0.2
# pyzmq                              24.0.1
# qdldl                              0.1.7.post4
# ratelim                            0.1.6
# referencing                        0.35.1
# regex                              2024.9.11
# requests                           2.32.3
# requests-oauthlib                  1.3.1
# requests-toolbelt                  1.0.0
# requirements-parser                0.9.0
# rich                               13.9.4
# rmm-cu12                           24.10.0
# rpds-py                            0.22.3
# rpy2                               3.4.2
# rsa                                4.9
# safetensors                        0.4.5
# scikit-image                       0.24.0
# scikit-learn                       1.5.2
# scipy                              1.13.1
# scooby                             0.10.0
# scs                                3.2.7
# seaborn                            0.13.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.3
# sentence-transformers              3.2.1
# sentencepiece                      0.2.0
# sentry-sdk                         2.19.0
# setproctitle                       1.3.4
# setuptools                         75.1.0
# shap                               0.46.0
# shapely                            2.0.6
# shellingham                        1.5.4
# simple-parsing                     0.1.6
# six                                1.16.0
# sklearn-pandas                     2.2.0
# slicer                             0.0.8
# smart-open                         7.0.5
# smmap                              5.0.1
# sniffio                            1.3.1
# snowballstemmer                    2.2.0
# soundfile                          0.12.1
# soupsieve                          2.6
# soxr                               0.5.0.post1
# spacy                              3.7.5
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.5
# Sphinx                             8.1.3
# sphinxcontrib-applehelp            2.0.0
# sphinxcontrib-devhelp              2.0.0
# sphinxcontrib-htmlhelp             2.1.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               2.0.0
# sphinxcontrib-serializinghtml      2.0.0
# SQLAlchemy                         2.0.36
# sqlglot                            25.1.0
# sqlparse                           0.5.2
# srsly                              2.4.8
# stanio                             0.5.1
# statsmodels                        0.14.4
# StrEnum                            0.4.15
# stringzilla                        3.11.0
# sympy                              1.13.1
# tables                             3.10.1
# tabulate                           0.9.0
# tbb                                2022.0.0
# tcmlib                             1.2.0
# tenacity                           9.0.0
# tensorboard                        2.18.0
# tensorboard-data-server            0.7.2
# tensorflow                         2.18.0
# tensorflow-datasets                4.9.7
# tensorflow_decision_forests        1.11.0
# tensorflow-hub                     0.16.1
# tensorflow-io-gcs-filesystem       0.37.1
# tensorflow-metadata                1.13.1
# tensorflow-probability             0.24.0
# tensorstore                        0.1.69
# termcolor                          2.5.0
# terminado                          0.18.1
# text-unidecode                     1.3
# textblob                           0.17.1
# tf_keras                           2.18.0
# tf-slim                            1.1.0
# thinc                              8.2.5
# threadpoolctl                      3.5.0
# tifffile                           2024.9.20
# timm                               1.0.12
# tinycss2                           1.4.0
# tokenizers                         0.20.3
# toml                               0.10.2
# tomli                              2.2.1
# toolz                              0.12.1
# torch                              2.5.1+cu121
# torchaudio                         2.5.1+cu121
# torchsummary                       1.5.1
# torchvision                        0.20.1+cu121
# tornado                            6.3.3
# tqdm                               4.66.6
# traitlets                          5.7.1
# traittypes                         0.2.1
# transformers                       4.46.3
# tweepy                             4.14.0
# typeguard                          4.4.1
# typer                              0.15.0
# types-pytz                         2024.2.0.20241003
# types-setuptools                   75.6.0.20241126
# typing_extensions                  4.12.2
# tzdata                             2024.2
# tzlocal                            5.2
# uc-micro-py                        1.0.3
# umf                                0.9.1
# uritemplate                        4.1.1
# urllib3                            2.2.3
# vega-datasets                      0.9.0
# wadllib                            1.3.6
# wandb                              0.18.7
# wasabi                             1.1.3
# wcwidth                            0.2.13
# weasel                             0.4.1
# webcolors                          24.11.1
# webencodings                       0.5.1
# websocket-client                   1.8.0
# Werkzeug                           3.1.3
# wheel                              0.45.1
# widgetsnbextension                 3.6.10
# wordcloud                          1.9.4
# wrapt                              1.17.0
# wurlitzer                          3.1.1
# xarray                             2024.10.0
# xarray-einstats                    0.8.0
# xgboost                            2.1.3
# xlrd                               2.0.1
# xyzservices                        2024.9.0
# yarl                               1.18.3
# ydf                                0.9.0
# yellowbrick                        1.5
# yfinance                           0.2.50
# zipp                               3.21.0

# %% [markdown]
# # Download and Import Library

# %%
# !pip install tensorflow_decision_forests
# !pip install colabtools
# Out:
# Requirement already satisfied: tensorflow_decision_forests in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (2.2.2)
# Requirement already satisfied: tensorflow==2.18.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (2.18.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (1.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (3.1.1)
# Requirement already satisfied: tf-keras~=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (2.18.0)
# Requirement already satisfied: ydf in /usr/local/lib/python3.10/dist-packages (from tensorflow_decision_forests) (0.9.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (3.5.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.18.0->tensorflow_decision_forests) (0.37.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->tensorflow_decision_forests) (2024.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow_decision_forests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow_decision_forests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow_decision_forests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow==2.18.0->tensorflow_decision_forests) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow_decision_forests) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow_decision_forests) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow_decision_forests) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow==2.18.0->tensorflow_decision_forests) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow==2.18.0->tensorflow_decision_forests) (0.1.2)
# Requirement already satisfied: colabtools in /usr/local/lib/python3.10/dist-packages (0.0.1)

# %%
import tensorflow_decision_forests as tfdf

import os
import numpy as np
import pandas as pd
import tensorflow as tf
import math

try:
  from wurlitzer import sys_pipes
except:
  from colabtools.googlelog import CaptureLog as sys_pipes

from IPython.core.magic import register_line_magic
from IPython.display import Javascript
# Check the version of TensorFlow Decision Forests
print("Found TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>
# Found TensorFlow Decision Forests v1.11.0

# %% [markdown]
# # Data Preprocession

# %% [markdown]
# ---
# - Vì dữ liệu chỉ có 2 trường `text` và `label` nên phải tiền xử lí dữ liệu trước khi đưa vào mô hình huấn luyện, nếu không mô hình sẽ tạo thành một rừng cây chỉ có một lá, và giá trị sẽ nghiêng hẳn về một label, mô hình không hoạt động đúng chức năng của nó.
# - Dùng cách tiền xử lí NLP cho dữ liệu:
#     - Tạo Vocab.
#     - Tokenizer data.
#     - Tối ưu siêu tham số (có hoặc không).
# ---

# %% [markdown]
# **Load Data**
# ---

# %%
#                        Load Data from google Drive

from google.colab import drive
import pandas as pd
import os

drive.mount('/content/drive', force_remount=True)

for dirname, _, filenames in os.walk('/content/drive/My Drive/Colab Notebooks'
):
    for filename in filenames:
        print(os.path.join(dirname, filename))

file_drive_path = ('/content/drive/My Drive/Colab Notebooks/train-00000-of-00001.parquet')

df = pd.read_parquet(file_drive_path)
df.head()
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks/Untitled0.ipynb
# /content/drive/My Drive/Colab Notebooks/RandomForestDEMO.ipynb
# /content/drive/My Drive/Colab Notebooks/NaiveBayesDEMO.ipynb
# /content/drive/My Drive/Colab Notebooks/LinearRegressionDEMO.ipynb
# /content/drive/My Drive/Colab Notebooks/LogisticRegressionDEMO.ipynb
# /content/drive/My Drive/Colab Notebooks/kaggle.json
# /content/drive/My Drive/Colab Notebooks/SVM.ipynb
# /content/drive/My Drive/Colab Notebooks/SVM_LinearDEMO.ipynb
# /content/drive/My Drive/Colab Notebooks/train-00000-of-00001.parquet
# /content/drive/My Drive/Colab Notebooks/Visuallize_Dataset.ipynb
# /content/drive/My Drive/Colab Notebooks/RandomForest_Lab01.ipynb
# /content/drive/My Drive/Colab Notebooks/nlp-getting-started/sample_submission.csv
# /content/drive/My Drive/Colab Notebooks/nlp-getting-started/test.csv
# /content/drive/My Drive/Colab Notebooks/nlp-getting-started/train.csv
# /content/drive/My Drive/Colab Notebooks/SVM_dataset/submission_instructions.txt
# /content/drive/My Drive/Colab Notebooks/SVM_dataset/submission_categories.txt
#                                                 text  label
# 0  i feel awful about it too because it s my job ...      0
# 1                              im alone i feel awful      0
# 2  ive probably mentioned this before but i reall...      1
# 3           i was feeling a little low few days back      0
# 4  i beleive that i am much more sensitive to oth...      2

# %%
#                        Load Data from local path

import pandas as pd

your_local_path = '' # Change your local path here

Local_file_path = your_local_path + 'train-00000-of-00001.parquet'

df = pd.read_parquet(Local_file_path)
df.head()

# %% [markdown]
# **Preprocess Data**
# ---

# %%
# Print Class Labels

label = "label"

classes = df[label].unique().tolist()
print(f"Label classes: {classes}")

df[label] = df[label].map(classes.index)
# Out:
# Label classes: [0, 1, 2, 3, 4, 5]

# %%
# Map Data

label_string = ['Sadness', 'Joy', 'Love', 'Anger', 'Fear', 'Surprise']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

vectorizer = TfidfVectorizer(stop_words='english', max_features=1000, min_df=5, max_df=0.9)
X = vectorizer.fit_transform(df['text'])  # Biến đổi văn bản thành ma trận TF-IDF
y = df['label']  # Nhãn của văn bản

# %%
for data in X:
    print(data)
    break
# Out:
#   (0, 293)	0.09348418155703282
#   (0, 51)	0.43010706204134014
#   (0, 465)	0.4059685966598052
#   (0, 649)	0.4966032845837647
#   (0, 470)	0.22943719661394182
#   (0, 199)	0.3883533371092306
#   (0, 375)	0.43747406507531744

# %%
# Change DataFrame Structure into Tensorflow Dataset

data = pd.DataFrame.sparse.from_spmatrix(X, columns=vectorizer.get_feature_names_out())
data['label'] = y

# %% [markdown]
# **Split Data**
# ---

# %%
from sklearn.model_selection import train_test_split

train_ds_pd, test_ds_pd = train_test_split(data, test_size=0.2, random_state=42)
print("{} examples in training, {} examples for testing.".format(
    train_ds_pd.shape[0], test_ds_pd.shape[0]))

train_dataset = tfdf.keras.pd_dataframe_to_tf_dataset(train_ds_pd, task=tfdf.keras.Task.CLASSIFICATION, label="label")
test_dataset = tfdf.keras.pd_dataframe_to_tf_dataset(test_ds_pd, task=tfdf.keras.Task.CLASSIFICATION, label="label")
# Out:
# 333447 examples in training, 83362 examples for testing.

# %% [markdown]
# # Build and Train Random Forest Model

# %%
# Specify the model.
model_1 = tfdf.keras.RandomForestModel(task=tfdf.keras.Task.CLASSIFICATION,estimator=100)

# Optionally, add evaluation metrics.
model_1.compile(
    metrics=["accuracy"])

# Train the model.
# "sys_pipes" is optional. It enables the display of the training logs.
with sys_pipes():
  model_1.fit(x=train_dataset)
# Out:
# Use /tmp/tmpdwmsihg9 as temporary training directory
# Reading training dataset...
# Training dataset read in 0:05:52.686357. Found 333447 examples.
# Training model...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733650918.189772    1741 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1733650918.195112    1741 kernel.cc:783] Collect training examples
# I0000 00:00:1733650918.196811    1741 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: false
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1733650918.206568    1741 kernel.cc:401] Number of batches: 334
# I0000 00:00:1733650918.210886    1741 kernel.cc:402] Number of examples: 333447
# I0000 00:00:1733650922.567895    1741 kernel.cc:802] Training dataset:
# Number of records: 333447
# Number of columns: 1001
#
# Number of columns by type:
# 	NUMERICAL: 1000 (99.9001%)
# 	CATEGORICAL: 1 (0.0999001%)
#
# Columns:
#
# NUMERICAL: 1000 (99.9001%)
# 	1: "ability" NUMERICAL mean:0.00082292 min:0 max:0.812029 sd:0.0200967
# 	2: "able" NUMERICAL mean:0.00423051 min:0 max:1 sd:0.0408584
# 	3: "absolutely" NUMERICAL mean:0.00182889 min:0 max:0.977679 sd:0.030938
# 	4: "abused" NUMERICAL mean:0.001857 min:0 max:0.994546 sd:0.0344742
# 	5: "accept" NUMERICAL mean:0.000753503 min:0 max:0.860179 sd:0.0194375
# 	6: "acceptable" NUMERICAL mean:0.00186996 min:0 max:0.994393 sd:0.0335311
# 	7: "accepted" NUMERICAL mean:0.00364478 min:0 max:1 sd:0.0451537
# 	8: "aching" NUMERICAL mean:0.00199316 min:0 max:0.978025 sd:0.0353154
# 	9: "act" NUMERICAL mean:0.000911686 min:0 max:0.981323 sd:0.0213901
# 	10: "actually" NUMERICAL mean:0.00486966 min:0 max:0.966539 sd:0.0440512
# 	11: "add" NUMERICAL mean:0.000799488 min:0 max:0.959273 sd:0.0200713
# 	12: "admit" NUMERICAL mean:0.00207639 min:0 max:0.976203 sd:0.0312956
# 	13: "adventurous" NUMERICAL mean:0.00171648 min:0 max:0.9791 sd:0.033018
# 	14: "afraid" NUMERICAL mean:0.00272036 min:0 max:1 sd:0.0380504
# 	15: "age" NUMERICAL mean:0.000884547 min:0 max:1 sd:0.0207714
# 	16: "agitated" NUMERICAL mean:0.00345644 min:0 max:0.973552 sd:0.0448863
# 	17: "ago" NUMERICAL mean:0.00168299 min:0 max:1 sd:0.0271398
# 	18: "ahead" NUMERICAL mean:0.000720311 min:0 max:0.873275 sd:0.0188041
# 	19: "air" NUMERICAL mean:0.000927274 min:0 max:0.98139 sd:0.0217017
# 	20: "alive" NUMERICAL mean:0.000801538 min:0 max:0.98263 sd:0.0210907
# 	21: "allow" NUMERICAL mean:0.000782468 min:0 max:0.921888 sd:0.0197684
# 	22: "allowed" NUMERICAL mean:0.000771082 min:0 max:0.982116 sd:0.0197265
# 	23: "amazed" NUMERICAL mean:0.00198248 min:0 max:0.977776 sd:0.0339949
# 	24: "amazing" NUMERICAL mean:0.00414175 min:0 max:0.992428 sd:0.04654
# 	25: "amp" NUMERICAL mean:0.00221432 min:0 max:0.989076 sd:0.032976
# 	26: "amused" NUMERICAL mean:0.0011617 min:0 max:0.981415 sd:0.0276629
# 	27: "anger" NUMERICAL mean:0.000992051 min:0 max:1 sd:0.0226244
# 	28: "angry" NUMERICAL mean:0.00378919 min:0 max:1 sd:0.0440574
# 	29: "annoyed" NUMERICAL mean:0.00241727 min:0 max:0.986022 sd:0.0375521
# 	30: "answer" NUMERICAL mean:0.000835066 min:0 max:0.995384 sd:0.0206888
# 	31: "anxiety" NUMERICAL mean:0.000714018 min:0 max:1 sd:0.0189009
# 	32: "anxious" NUMERICAL mean:0.00271295 min:0 max:0.993508 sd:0.0380527
# 	33: "anymore" NUMERICAL mean:0.00205605 min:0 max:0.976218 sd:0.0312586
# 	34: "appreciate" NUMERICAL mean:0.000731514 min:0 max:0.982403 sd:0.019146
# 	35: "appreciative" NUMERICAL mean:0.00135381 min:0 max:0.980482 sd:0.0294144
# 	36: "apprehensive" NUMERICAL mean:0.0018429 min:0 max:0.978315 sd:0.0331334
# 	37: "area" NUMERICAL mean:0.000660034 min:0 max:0.982946 sd:0.0184058
# 	38: "arent" NUMERICAL mean:0.000743322 min:0 max:0.982362 sd:0.0191258
# 	39: "arms" NUMERICAL mean:0.000862209 min:0 max:0.981838 sd:0.020929
# 	40: "art" NUMERICAL mean:0.000920852 min:0 max:0.981558 sd:0.0219085
# 	41: "artistic" NUMERICAL mean:0.00144278 min:0 max:0.980172 sd:0.0301101
# 	42: "ashamed" NUMERICAL mean:0.00201473 min:0 max:0.9779 sd:0.0350805
# 	43: "ask" NUMERICAL mean:0.00186453 min:0 max:0.97687 sd:0.0294078
# 	44: "asked" NUMERICAL mean:0.00154606 min:0 max:1 sd:0.0276005
# 	45: "asking" NUMERICAL mean:0.000907976 min:0 max:0.981421 sd:0.0213677
# 	46: "assaulted" NUMERICAL mean:0.000985924 min:0 max:1 sd:0.0256895
# 	47: "assured" NUMERICAL mean:0.00174449 min:0 max:0.97845 sd:0.0320328
# 	48: "attention" NUMERICAL mean:0.00104707 min:0 max:0.980471 sd:0.0223366
# 	49: "aware" NUMERICAL mean:0.000683793 min:0 max:0.814134 sd:0.018386
# 	50: "away" NUMERICAL mean:0.00433979 min:0 max:1 sd:0.0408937
# 	51: "awesome" NUMERICAL mean:0.000666235 min:0 max:0.864863 sd:0.0179054
# 	52: "awful" NUMERICAL mean:0.00208467 min:0 max:0.977185 sd:0.0347538
# 	53: "awkward" NUMERICAL mean:0.00212956 min:0 max:0.976965 sd:0.0346744
# 	54: "baby" NUMERICAL mean:0.00177883 min:0 max:0.976909 sd:0.0286267
# 	55: "bad" NUMERICAL mean:0.00438674 min:0 max:1 sd:0.0455834
# 	56: "badly" NUMERICAL mean:0.000759919 min:0 max:1 sd:0.0199632
# 	57: "beaten" NUMERICAL mean:0.00193986 min:0 max:0.978405 sd:0.034934
# 	58: "beautiful" NUMERICAL mean:0.00144791 min:0 max:0.978315 sd:0.0257614
# 	59: "bed" NUMERICAL mean:0.00203192 min:0 max:1 sd:0.0300663
# 	60: "began" NUMERICAL mean:0.00180536 min:0 max:1 sd:0.0311765
# 	61: "begin" NUMERICAL mean:0.00119229 min:0 max:0.980024 sd:0.0244882
# 	62: "beginning" NUMERICAL mean:0.00124593 min:0 max:0.979966 sd:0.0255562
# 	63: "believe" NUMERICAL mean:0.00240014 min:0 max:0.974109 sd:0.0320201
# 	64: "beloved" NUMERICAL mean:0.00266767 min:0 max:1 sd:0.0391067
# 	65: "best" NUMERICAL mean:0.00244701 min:0 max:0.973841 sd:0.0319818
# 	66: "better" NUMERICAL mean:0.00504923 min:0 max:0.99617 sd:0.0477533
# 	67: "big" NUMERICAL mean:0.00197093 min:0 max:1 sd:0.0291363
# 	68: "birthday" NUMERICAL mean:0.000674001 min:0 max:1 sd:0.0185042
# 	69: "bit" NUMERICAL mean:0.0106297 min:0 max:0.954065 sd:0.0638368
# 	70: "bitchy" NUMERICAL mean:0.00199183 min:0 max:1 sd:0.0357104
# 	71: "bitter" NUMERICAL mean:0.00201973 min:0 max:0.99424 sd:0.0345325
# 	72: "black" NUMERICAL mean:0.00074128 min:0 max:0.894976 sd:0.0192118
# 	73: "blamed" NUMERICAL mean:0.0008712 min:0 max:1 sd:0.0241315
# 	74: "blank" NUMERICAL mean:0.00175687 min:0 max:1 sd:0.0318803
# 	75: "blessed" NUMERICAL mean:0.0039772 min:0 max:0.971924 sd:0.0473431
# 	76: "blog" NUMERICAL mean:0.00321838 min:0 max:0.971603 sd:0.0373823
# 	77: "blogging" NUMERICAL mean:0.000815699 min:0 max:0.811514 sd:0.0203003
# 	78: "body" NUMERICAL mean:0.003066 min:0 max:0.972439 sd:0.0366477
# 	79: "book" NUMERICAL mean:0.00244462 min:0 max:0.974454 sd:0.0332628
# 	80: "books" NUMERICAL mean:0.00118524 min:0 max:1 sd:0.0238823
# 	81: "boring" NUMERICAL mean:0.0019549 min:0 max:0.977713 sd:0.0337643
# 	82: "bothered" NUMERICAL mean:0.00203745 min:0 max:0.994213 sd:0.0345785
# 	83: "boy" NUMERICAL mean:0.00109049 min:0 max:1 sd:0.0232822
# 	84: "boyfriend" NUMERICAL mean:0.000821974 min:0 max:1 sd:0.0209328
# 	85: "brain" NUMERICAL mean:0.000865598 min:0 max:0.981825 sd:0.0207726
# 	86: "brave" NUMERICAL mean:0.00190107 min:0 max:0.987083 sd:0.0337578
# 	87: "break" NUMERICAL mean:0.00125417 min:0 max:0.979372 sd:0.0242937
# 	88: "breath" NUMERICAL mean:0.000676253 min:0 max:0.982999 sd:0.0189767
# 	89: "bring" NUMERICAL mean:0.0011502 min:0 max:0.979795 sd:0.0229465
# 	90: "broke" NUMERICAL mean:0.00181309 min:0 max:1 sd:0.0325923
# 	91: "brother" NUMERICAL mean:0.000679913 min:0 max:1 sd:0.0190983
# 	92: "burdened" NUMERICAL mean:0.00188533 min:0 max:0.994514 sd:0.0345965
# 	93: "business" NUMERICAL mean:0.000702106 min:0 max:0.982659 sd:0.0188708
# 	94: "busy" NUMERICAL mean:0.000902913 min:0 max:1 sd:0.0208625
# 	95: "buy" NUMERICAL mean:0.00100778 min:0 max:0.980832 sd:0.0222489
# 	96: "called" NUMERICAL mean:0.00114114 min:0 max:1 sd:0.0232439
# 	97: "calm" NUMERICAL mean:0.00235819 min:0 max:0.976267 sd:0.0368629
# 	98: "came" NUMERICAL mean:0.00224018 min:0 max:1 sd:0.0314491
# 	99: "car" NUMERICAL mean:0.00114382 min:0 max:1 sd:0.0247824
# 	100: "care" NUMERICAL mean:0.00250184 min:0 max:0.973888 sd:0.0328311
# 	101: "career" NUMERICAL mean:0.000663281 min:0 max:0.983083 sd:0.018715
# 	102: "carefree" NUMERICAL mean:0.00142684 min:0 max:0.980018 sd:0.0299173
# 	103: "caring" NUMERICAL mean:0.00206767 min:0 max:0.976929 sd:0.0334118
# 	104: "case" NUMERICAL mean:0.00104652 min:0 max:0.980616 sd:0.0225538
# 	105: "casual" NUMERICAL mean:0.00147863 min:0 max:0.979769 sd:0.0298908
# 	106: "caught" NUMERICAL mean:0.000693224 min:0 max:1 sd:0.0191706
# 	107: "cause" NUMERICAL mean:0.00159275 min:0 max:0.977433 sd:0.0264802
# 	108: "certain" NUMERICAL mean:0.00137889 min:0 max:1 sd:0.0254059
# 	109: "certainly" NUMERICAL mean:0.000967041 min:0 max:0.85924 sd:0.0218167
# 	110: "chance" NUMERICAL mean:0.00106507 min:0 max:0.980226 sd:0.0223897
# 	111: "change" NUMERICAL mean:0.0020785 min:0 max:1 sd:0.0303464
# 	112: "character" NUMERICAL mean:0.00085226 min:0 max:0.981923 sd:0.0210701
# 	113: "characters" NUMERICAL mean:0.000723253 min:0 max:0.982681 sd:0.0193157
# 	114: "charming" NUMERICAL mean:0.00072487 min:0 max:0.995796 sd:0.0217854
# 	115: "check" NUMERICAL mean:0.000660858 min:0 max:0.840777 sd:0.0181669
# 	116: "child" NUMERICAL mean:0.00191284 min:0 max:1 sd:0.0305285
# 	117: "children" NUMERICAL mean:0.0019685 min:0 max:1 sd:0.0299808
# 	118: "choice" NUMERICAL mean:0.000715522 min:0 max:0.982842 sd:0.019364
# 	119: "choose" NUMERICAL mean:0.00086202 min:0 max:0.961634 sd:0.0210381
# 	120: "christmas" NUMERICAL mean:0.00121801 min:0 max:1 sd:0.0244658
# 	121: "church" NUMERICAL mean:0.000976602 min:0 max:0.916405 sd:0.0221934
# 	122: "city" NUMERICAL mean:0.000914076 min:0 max:0.981533 sd:0.0215381
# 	123: "class" NUMERICAL mean:0.00221841 min:0 max:1 sd:0.0321739
# 	124: "clean" NUMERICAL mean:0.00064111 min:0 max:0.983114 sd:0.0178633
# 	125: "clever" NUMERICAL mean:0.00186286 min:0 max:0.978673 sd:0.0342688
# 	126: "close" NUMERICAL mean:0.00158642 min:0 max:1 sd:0.0273869
# 	127: "clothes" NUMERICAL mean:0.000842139 min:0 max:0.981754 sd:0.0203876
# 	128: "cold" NUMERICAL mean:0.00295764 min:0 max:0.974346 sd:0.040402
# 	129: "college" NUMERICAL mean:0.000815249 min:0 max:1 sd:0.0201312
# 	130: "come" NUMERICAL mean:0.00435891 min:0 max:1 sd:0.0410081
# 	131: "comes" NUMERICAL mean:0.00181818 min:0 max:0.976624 sd:0.0285359
# 	132: "comfort" NUMERICAL mean:0.000739957 min:0 max:0.846956 sd:0.019044
# 	133: "comfortable" NUMERICAL mean:0.00275001 min:0 max:0.974851 sd:0.0387315
# 	134: "coming" NUMERICAL mean:0.00227858 min:0 max:1 sd:0.0322604
# 	135: "comment" NUMERICAL mean:0.00082905 min:0 max:0.982089 sd:0.0208993
# 	136: "comments" NUMERICAL mean:0.000919139 min:0 max:0.981366 sd:0.0213158
# 	137: "community" NUMERICAL mean:0.00115409 min:0 max:0.980421 sd:0.0243232
# 	138: "company" NUMERICAL mean:0.000816466 min:0 max:0.83777 sd:0.020562
# 	139: "compassionate" NUMERICAL mean:0.000999379 min:0 max:0.982042 sd:0.0251219
# 	140: "complacent" NUMERICAL mean:0.00110312 min:0 max:0.981877 sd:0.0269803
# 	141: "complete" NUMERICAL mean:0.000721087 min:0 max:0.982502 sd:0.0188637
# 	142: "completely" NUMERICAL mean:0.00351468 min:0 max:0.971465 sd:0.0400878
# 	143: "confidence" NUMERICAL mean:0.000673508 min:0 max:0.821399 sd:0.0184798
# 	144: "confident" NUMERICAL mean:0.00266791 min:0 max:0.993652 sd:0.038698
# 	145: "confused" NUMERICAL mean:0.00233146 min:0 max:0.976263 sd:0.0362065
# 	146: "connection" NUMERICAL mean:0.000771237 min:0 max:0.982502 sd:0.0203686
# 	147: "constantly" NUMERICAL mean:0.00125089 min:0 max:0.979718 sd:0.0251001
# 	148: "content" NUMERICAL mean:0.00223482 min:0 max:0.994012 sd:0.0357403
# 	149: "contented" NUMERICAL mean:0.00148224 min:0 max:1 sd:0.0311592
# 	150: "continue" NUMERICAL mean:0.00135354 min:0 max:0.857339 sd:0.0250946
# 	151: "control" NUMERICAL mean:0.00166983 min:0 max:0.977717 sd:0.0285726
# 	152: "conversation" NUMERICAL mean:0.000900547 min:0 max:0.981403 sd:0.0210299
# 	153: "convinced" NUMERICAL mean:0.00174947 min:0 max:0.978121 sd:0.0311725
# 	154: "cool" NUMERICAL mean:0.00231617 min:0 max:0.986668 sd:0.0359868
# 	155: "couldn" NUMERICAL mean:0.0010028 min:0 max:0.981036 sd:0.0225869
# 	156: "country" NUMERICAL mean:0.00109924 min:0 max:1 sd:0.0238506
# 	157: "couple" NUMERICAL mean:0.00160008 min:0 max:0.977529 sd:0.0263377
# 	158: "course" NUMERICAL mean:0.00133766 min:0 max:1 sd:0.0251659
# 	159: "cranky" NUMERICAL mean:0.00190171 min:0 max:0.978302 sd:0.0340846
# 	160: "crap" NUMERICAL mean:0.000743152 min:0 max:0.922019 sd:0.0196356
# 	161: "crappy" NUMERICAL mean:0.0018073 min:0 max:0.978275 sd:0.0323438
# 	162: "crazy" NUMERICAL mean:0.00101811 min:0 max:0.890096 sd:0.0220642
# 	163: "create" NUMERICAL mean:0.0007414 min:0 max:0.749264 sd:0.018986
# 	164: "creative" NUMERICAL mean:0.0023313 min:0 max:0.97654 sd:0.0363531
# 	165: "crying" NUMERICAL mean:0.000867386 min:0 max:0.958483 sd:0.0205519
# 	166: "curious" NUMERICAL mean:0.00191532 min:0 max:0.978187 sd:0.0339776
# 	167: "currently" NUMERICAL mean:0.000727397 min:0 max:0.982879 sd:0.0196445
# 	168: "cut" NUMERICAL mean:0.000720513 min:0 max:0.960804 sd:0.0188953
# 	169: "cute" NUMERICAL mean:0.00205286 min:0 max:0.977193 sd:0.034232
# 	170: "dad" NUMERICAL mean:0.000800552 min:0 max:0.982136 sd:0.020064
# 	171: "daily" NUMERICAL mean:0.000784019 min:0 max:0.842007 sd:0.0193856
# 	172: "damaged" NUMERICAL mean:0.00171897 min:0 max:1 sd:0.0335141
# 	173: "damn" NUMERICAL mean:0.0011781 min:0 max:0.980394 sd:0.0250583
# 	174: "dangerous" NUMERICAL mean:0.00195694 min:0 max:0.97813 sd:0.0348662
# 	175: "dark" NUMERICAL mean:0.000857658 min:0 max:1 sd:0.0207966
# 	176: "daughter" NUMERICAL mean:0.000728356 min:0 max:1 sd:0.0190116
# 	177: "day" NUMERICAL mean:0.00867866 min:0 max:1 sd:0.0564892
# 	178: "days" NUMERICAL mean:0.00516177 min:0 max:1 sd:0.045837
# 	179: "dazed" NUMERICAL mean:0.00125434 min:0 max:0.980832 sd:0.028195
# 	180: "deal" NUMERICAL mean:0.00104959 min:0 max:0.812491 sd:0.0219874
# 	181: "death" NUMERICAL mean:0.00108597 min:0 max:1 sd:0.0239785
# 	182: "decided" NUMERICAL mean:0.00186607 min:0 max:1 sd:0.0287197
# 	183: "decision" NUMERICAL mean:0.000868358 min:0 max:0.981793 sd:0.0212682
# 	184: "deep" NUMERICAL mean:0.00112385 min:0 max:0.980029 sd:0.0229987
# 	185: "deeply" NUMERICAL mean:0.000972516 min:0 max:0.98128 sd:0.0226531
# 	186: "defeated" NUMERICAL mean:0.00201327 min:0 max:0.978178 sd:0.0352882
# 	187: "definitely" NUMERICAL mean:0.00161029 min:0 max:0.977874 sd:0.0276527
# 	188: "delicate" NUMERICAL mean:0.00150673 min:0 max:0.979779 sd:0.0306888
# 	189: "delicious" NUMERICAL mean:0.001788 min:0 max:0.978472 sd:0.0325738
# 	190: "delighted" NUMERICAL mean:0.00115916 min:0 max:0.98136 sd:0.027244
# 	191: "depressed" NUMERICAL mean:0.00290035 min:0 max:0.993414 sd:0.0397379
# 	192: "deprived" NUMERICAL mean:0.00180182 min:0 max:1 sd:0.0328142
# 	193: "deserve" NUMERICAL mean:0.000803037 min:0 max:0.982258 sd:0.0205619
# 	194: "desire" NUMERICAL mean:0.000910261 min:0 max:0.981602 sd:0.0217417
# 	195: "despite" NUMERICAL mean:0.00104107 min:0 max:1 sd:0.0220198
# 	196: "determined" NUMERICAL mean:0.00199637 min:0 max:0.977764 sd:0.034416
# 	197: "devastated" NUMERICAL mean:0.00178777 min:0 max:0.978779 sd:0.03333
# 	198: "devoted" NUMERICAL mean:0.000775196 min:0 max:0.982842 sd:0.021628
# 	199: "did" NUMERICAL mean:0.0069918 min:0 max:1 sd:0.0525653
# 	200: "didn" NUMERICAL mean:0.00321835 min:0 max:0.972228 sd:0.0387783
# 	201: "didnt" NUMERICAL mean:0.00639266 min:0 max:1 sd:0.0515813
# 	202: "die" NUMERICAL mean:0.000640918 min:0 max:0.899561 sd:0.01793
# 	203: "different" NUMERICAL mean:0.00170617 min:0 max:0.977044 sd:0.0276369
# 	204: "difficult" NUMERICAL mean:0.000784736 min:0 max:1 sd:0.0194441
# 	205: "dinner" NUMERICAL mean:0.000722806 min:0 max:0.960162 sd:0.018709
# 	206: "dirty" NUMERICAL mean:0.00191261 min:0 max:0.997524 sd:0.0345927
# 	207: "disappointed" NUMERICAL mean:0.00235516 min:0 max:0.97617 sd:0.0364685
# 	208: "discontent" NUMERICAL mean:0.00166404 min:0 max:0.979446 sd:0.03
# I0000 00:00:1733650922.568870    1741 kernel.cc:818] Configure learner
# I0000 00:00:1733650922.570115    1741 kernel.cc:831] Training config:
# learner: "RANDOM_FOREST"
# features: "^ability$"
# features: "^able$"
# features: "^absolutely$"
# features: "^abused$"
# features: "^accept$"
# features: "^acceptable$"
# features: "^accepted$"
# features: "^aching$"
# features: "^act$"
# features: "^actually$"
# features: "^add$"
# features: "^admit$"
# features: "^adventurous$"
# features: "^afraid$"
# features: "^age$"
# features: "^agitated$"
# features: "^ago$"
# features: "^ahead$"
# features: "^air$"
# features: "^alive$"
# features: "^allow$"
# features: "^allowed$"
# features: "^amazed$"
# features: "^amazing$"
# features: "^amp$"
# features: "^amused$"
# features: "^anger$"
# features: "^angry$"
# features: "^annoyed$"
# features: "^answer$"
# features: "^anxiety$"
# features: "^anxious$"
# features: "^anymore$"
# features: "^appreciate$"
# features: "^appreciative$"
# features: "^apprehensive$"
# features: "^area$"
# features: "^arent$"
# features: "^arms$"
# features: "^art$"
# features: "^artistic$"
# features: "^ashamed$"
# features: "^ask$"
# features: "^asked$"
# features: "^asking$"
# features: "^assaulted$"
# features: "^assured$"
# features: "^attention$"
# features: "^aware$"
# features: "^away$"
# features: "^awesome$"
# features: "^awful$"
# features: "^awkward$"
# features: "^baby$"
# features: "^bad$"
# features: "^badly$"
# features: "^beaten$"
# features: "^beautiful$"
# features: "^bed$"
# features: "^began$"
# features: "^begin$"
# features: "^beginning$"
# features: "^believe$"
# features: "^beloved$"
# features: "^best$"
# features: "^better$"
# features: "^big$"
# features: "^birthday$"
# features: "^bit$"
# features: "^bitchy$"
# features: "^bitter$"
# features: "^black$"
# features: "^blamed$"
# features: "^blank$"
# features: "^blessed$"
# features: "^blog$"
# features: "^blogging$"
# features: "^body$"
# features: "^book$"
# features: "^books$"
# features: "^boring$"
# features: "^bothered$"
# features: "^boy$"
# features: "^boyfriend$"
# features: "^brain$"
# features: "^brave$"
# features: "^break$"
# features: "^breath$"
# features: "^bring$"
# features: "^broke$"
# features: "^brother$"
# features: "^burdened$"
# features: "^business$"
# features: "^busy$"
# features: "^buy$"
# features: "^called$"
# features: "^calm$"
# features: "^came$"
# features: "^car$"
# features: "^care$"
# features: "^career$"
# features: "^carefree$"
# features: "^caring$"
# features: "^case$"
# features: "^casual$"
# features: "^caught$"
# features: "^cause$"
# features: "^certain$"
# features: "^certainly$"
# features: "^chance$"
# features: "^change$"
# features: "^character$"
# features: "^characters$"
# features: "^charming$"
# features: "^check$"
# features: "^child$"
# features: "^children$"
# features: "^choice$"
# features: "^choose$"
# features: "^christmas$"
# features: "^church$"
# features: "^city$"
# features: "^class$"
# features: "^clean$"
# features: "^clever$"
# features: "^close$"
# features: "^clothes$"
# features: "^cold$"
# features: "^college$"
# features: "^come$"
# features: "^comes$"
# features: "^comfort$"
# features: "^comfortable$"
# features: "^coming$"
# features: "^comment$"
# features: "^comments$"
# features: "^community$"
# features: "^company$"
# features: "^compassionate$"
# features: "^complacent$"
# features: "^complete$"
# features: "^completely$"
# features: "^confidence$"
# features: "^confident$"
# features: "^confused$"
# features: "^connection$"
# features: "^constantly$"
# features: "^content$"
# features: "^contented$"
# features: "^continue$"
# features: "^control$"
# features: "^conversation$"
# features: "^convinced$"
# features: "^cool$"
# features: "^couldn$"
# features: "^country$"
# features: "^couple$"
# features: "^course$"
# features: "^cranky$"
# features: "^crap$"
# features: "^crappy$"
# features: "^crazy$"
# features: "^create$"
# features: "^creative$"
# features: "^crying$"
# features: "^curious$"
# features: "^currently$"
# features: "^cut$"
# features: "^cute$"
# features: "^dad$"
# features: "^daily$"
# features: "^damaged$"
# features: "^damn$"
# features: "^dangerous$"
# features: "^dark$"
# features: "^daughter$"
# features: "^day$"
# features: "^days$"
# features: "^dazed$"
# features: "^deal$"
# features: "^death$"
# features: "^decided$"
# features: "^decision$"
# features: "^deep$"
# features: "^deeply$"
# features: "^defeated$"
# features: "^definitely$"
# features: "^delicate$"
# features: "^delicious$"
# features: "^delighted$"
# features: "^depressed$"
# features: "^deprived$"
# features: "^deserve$"
# features: "^desire$"
# features: "^despite$"
# features: "^determined$"
# features: "^devastated$"
# features: "^devoted$"
# features: "^did$"
# features: "^didn$"
# features: "^didnt$"
# features: "^die$"
# features: "^different$"
# features: "^difficult$"
# features: "^dinner$"
# features: "^dirty$"
# features: "^disappointed$"
# features: "^discontent$"
# features: "^discouraged$"
# features: "^disgusted$"
# features: "^disheartened$"
# features: "^disillusioned$"
# features: "^dissatisfied$"
# features: "^distracted$"
# features: "^distraught$"
# features: "^distressed$"
# features: "^disturbed$"
# features: "^divine$"
# features: "^does$"
# features: "^doesn$"
# features: "^doesnt$"
# features: "^doing$"
# features: "^don$"
# features: "^dont$"
# features: "^doomed$"
# features: "^door$"
# features: "^doubt$"
# features: "^doubtful$"
# features: "^drained$"
# features: "^dream$"
# features: "^dreams$"
# features: "^dress$"
# features: "^drink$"
# features: "^drive$"
# features: "^dull$"
# features: "^dumb$"
# features: "^eager$"
# features: "^early$"
# features: "^earth$"
# features: "^easily$"
# features: "^easy$"
# features: "^eat$"
# features: "^eating$"
# features: "^ecstatic$"
# features: "^effort$"
# features: "^elegant$"
# features: "^embarrassed$"
# features: "^emotion$"
# features: "^emotional$"
# features: "^emotionally$"
# features: "^emotions$"
# features: "^end$"
# features: "^ended$"
# features: "^energetic$"
# features: "^energy$"
# features: "^enjoy$"
# features: "^enjoyed$"
# features: "^enjoying$"
# features: "^entertained$"
# features: "^entire$"
# features: "^envious$"
# features: "^especially$"
# features: "^evening$"
# features: "^events$"
# features: "^everyday$"
# features: "^exactly$"
# features: "^excited$"
# features: "^exhausted$"
# features: "^expect$"
# features: "^experience$"
# features: "^experiences$"
# features: "^explain$"
# features: "^express$"
# features: "^extremely$"
# features: "^eye$"
# features: "^eyes$"
# features: "^fabulous$"
# features: "^face$"
# features: "^facebook$"
# features: "^fact$"
# features: "^fairly$"
# features: "^faith$"
# features: "^faithful$"
# features: "^fake$"
# features: "^fall$"
# features: "^family$"
# features: "^fantastic$"
# features: "^far$"
# features: "^fast$"
# features: "^fat$"
# features: "^father$"
# features: "^fear$"
# features: "^fearful$"
# features: "^feel$"
# features: "^feeling$"
# features: "^feelings$"
# features: "^feels$"
# features: "^feet$"
# features: "^felt$"
# features: "^festive$"
# features: "^fight$"
# features: "^figure$"
# features: "^film$"
# features: "^finally$"
# features: "^finding$"
# features: "^fine$"
# features: "^finish$"
# features: "^finished$"
# features: "^fit$"
# features: "^focus$"
# features: "^follow$"
# features: "^fond$"
# features: "^food$"
# features: "^foolish$"
# features: "^forever$"
# features: "^forget$"
# features: "^form$"
# features: "^forward$"
# features: "^frantic$"
# features: "^free$"
# features: "^friend$"
# features: "^friendly$"
# features: "^friends$"
# features: "^frightened$"
# features: "^frustrated$"
# features: "^fucked$"
# features: "^fucking$"
# features: "^fully$"
# features: "^fun$"
# features: "^funny$"
# features: "^future$"
# features: "^game$"
# features: "^gave$"
# features: "^general$"
# features: "^generally$"
# features: "^generous$"
# features: "^gentle$"
# features: "^gets$"
# features: "^getting$"
# features: "^gift$"
# features: "^girl$"
# features: "^girls$"
# features: "^given$"
# features: "^gives$"
# features: "^giving$"
# features: "^glad$"
# features: "^glamorous$"
# features: "^gloomy$"
# features: "^god$"
# features: "^goes$"
# features: "^going$"
# features: "^gone$"
# features: "^gonna$"
# features: "^good$"
# features: "^gorgeous$"
# features: "^got$"
# features: "^gotten$"
# features: "^gracious$"
# features: "^grateful$"
# features: "^great$"
# features: "^greedy$"
# features: "^groggy$"
# features: "^grouchy$"
# features: "^group$"
# features: "^grow$"
# features: "^grumpy$"
# features: "^guess$"
# features: "^guilt$"
# features: "^guilty$"
# features: "^guy$"
# features: "^guys$"
# features: "^hair$"
# features: "^half$"
# features: "^hand$"
# features: "^hands$"
# features: "^happen$"
# features: "^happened$"
# features: "^happening$"
# features: "^happens$"
# features: "^happiness$"
# features: "^happy$"
# features: "^hard$"
# features: "^hate$"
# features: "^hated$"
# features: "^hateful$"
# features: "^haven$"
# features: "^havent$"
# features: "^having$"
# features: "^head$"
# features: "^health$"
# features: "^healthy$"
# features: "^hear$"
# features: "^heard$"
# features: "^heart$"
# features: "^heartbroken$"
# features: "^heartless$"
# features: "^hell$"
# features: "^help$"
# features: "^helped$"
# features: "^helping$"
# features: "^helpless$"
# features: "^hes$"
# features: "^hesitant$"
# features: "^high$"
# features: "^hit$"
# features: "^hold$"
# features: "^holiday$"
# features: "^home$"
# features: "^homesick$"
# features: "^honest$"
# features: "^honestly$"
# features: "^honored$"
# features: "^honoured$"
# features: "^hope$"
# features: "^hopeful$"
# features: "^hopeless$"
# features: "^hoping$"
# features: "^horny$"
# features: "^horrible$"
# features: "^hostile$"
# features: "^hot$"
# features: "^hour$"
# features: "^hours$"
# features: "^house$"
# features: "^href$"
# features: "^http$"
# features: "^huge$"
# features: "^human$"
# features: "^humiliated$"
# features: "^hurt$"
# features: "^husband$"
# features: "^id$"
# features: "^idea$"
# features: "^ideas$"
# features: "^idiotic$"
# features: "^ignored$"
# features: "^ill$"
# features: "^im$"
# features: "^imagine$"
# features: "^img$"
# features: "^impatient$"
# features: "^important$"
# features: "^impressed$"
# features: "^inadequate$"
# features: "^incredibly$"
# features: "^information$"
# features: "^inhibited$"
# features: "^innocent$"
# features: "^insecure$"
# features: "^inside$"
# features: "^inspired$"
# features: "^instead$"
# features: "^insulted$"
# features: "^intelligent$"
# features: "^intimidated$"
# features: "^invigorated$"
# features: "^irritable$"
# features: "^irritated$"
# features: "^isnt$"
# features: "^isolated$"
# features: "^issue$"
# features: "^issues$"
# features: "^ive$"
# features: "^jaded$"
# features: "^jealous$"
# features: "^job$"
# features: "^jolly$"
# features: "^journey$"
# features: "^joy$"
# features: "^joyful$"
# features: "^just$"
# features: "^keen$"
# features: "^keeping$"
# features: "^kept$"
# features: "^kid$"
# features: "^kids$"
# features: "^kind$"
# features: "^kinda$"
# features: "^knew$"
# features: "^know$"
# features: "^knowing$"
# features: "^known$"
# features: "^knows$"
# features: "^lack$"
# features: "^lame$"
# features: "^late$"
# features: "^lately$"
# features: "^later$"
# features: "^laugh$"
# features: "^learn$"
# features: "^learned$"
# features: "^learning$"
# features: "^leave$"
# features: "^leaves$"
# features: "^leaving$"
# features: "^left$"
# features: "^legs$"
# features: "^let$"
# features: "^lethargic$"
# features: "^letting$"
# features: "^level$"
# features: "^life$"
# features: "^light$"
# features: "^like$"
# features: "^liked$"
# features: "^line$"
# features: "^list$"
# features: "^listen$"
# features: "^listening$"
# features: "^listless$"
# features: "^little$"
# features: "^live$"
# features: "^lively$"
# features: "^lives$"
# features: "^living$"
# features: "^ll$"
# features: "^lol$"
# features: "^lonely$"
# features: "^long$"
# features: "^longer$"
# features: "^longing$"
# features: "^look$"
# features: "^looked$"
# features: "^looking$"
# features: "^looks$"
# features: "^lord$"
# features: "^lose$"
# features: "^losing$"
# features: "^loss$"
# features: "^lost$"
# features: "^lot$"
# features: "^lots$"
# features: "^lousy$"
# features: "^love$"
# features: "^loved$"
# features: "^lovely$"
# features: "^loving$"
# features: "^low$"
# features: "^loyal$"
# features: "^lucky$"
# features: "^mad$"
# features: "^make$"
# features: "^makes$"
# features: "^making$"
# features: "^man$"
# features: "^managed$"
# features: "^matter$"
# features: "^maybe$"
# features: "^mean$"
# features: "^means$"
# features: "^meant$"
# features: "^meet$"
# features: "^meeting$"
# features: "^melancholy$"
# features: "^mellow$"
# features: "^memories$"
# features: "^men$"
# features: "^messy$"
# features: "^met$"
# features: "^middle$"
# features: "^mind$"
# features: "^minute$"
# features: "^minutes$"
# features: "^miserable$"
# features: "^miss$"
# features: "^missed$"
# features: "^missing$"
# features: "^mom$"
# features: "^moment$"
# features: "^moments$"
# features: "^money$"
# features: "^month$"
# features: "^months$"
# features: "^mood$"
# features: "^morning$"
# features: "^mother$"
# features: "^movie$"
# features: "^moving$"
# features: "^music$"
# features: "^nature$"
# features: "^naughty$"
# features: "^near$"
# features: "^need$"
# features: "^needed$"
# features: "^needs$"
# features: "^needy$"
# features: "^negative$"
# features: "^nervous$"
# features: "^new$"
# features: "^news$"
# features: "^nice$"
# features: "^night$"
# features: "^normal$"
# features: "^nostalgic$"
# features: "^noticed$"
# features: "^numb$"
# features: "^number$"
# features: "^offended$"
# features: "^offer$"
# features: "^office$"
# features: "^oh$"
# features: "^ok$"
# features: "^okay$"
# features: "^old$"
# features: "^ones$"
# features: "^online$"
# features: "^open$"
# features: "^opportunity$"
# features: "^optimistic$"
# features: "^order$"
# features: "^outside$"
# features: "^overwhelmed$"
# features: "^pain$"
# features: "^paranoid$"
# features: "^parents$"
# features: "^particular$"
# features: "^particularly$"
# features: "^party$"
# features: "^pass$"
# features: "^passionate$"
# features: "^past$"
# features: "^pathetic$"
# features: "^pay$"
# features: "^peace$"
# features: "^peaceful$"
# features: "^people$"
# features: "^perfect$"
# features: "^person$"
# features: "^personal$"
# features: "^personally$"
# features: "^petty$"
# features: "^phone$"
# features: "^photos$"
# features: "^physically$"
# features: "^pick$"
# features: "^picture$"
# features: "^pictures$"
# features: "^piece$"
# features: "^pissed$"
# features: "^place$"
# features: "^places$"
# features: "^plan$"
# features: "^play$"
# features: "^playful$"
# features: "^playing$"
# features: "^pleasant$"
# features: "^pleased$"
# features: "^point$"
# features: "^popular$"
# features: "^position$"
# features: "^positive$"
# features: "^possible$"
# features: "^possibly$"
# features: "^post$"
# features: "^posting$"
# features: "^posts$"
# features: "^power$"
# features: "^precious$"
# features: "^pregnant$"
# features: "^presence$"
# features: "^present$"
# features: "^pressure$"
# features: "^pressured$"
# features: "^pretty$"
# features: "^privileged$"
# features: "^probably$"
# features: "^problem$"
# features: "^problems$"
# features: "^process$"
# features: "^productive$"
# features: "^project$"
# features: "^proud$"
# features: "^public$"
# features: "^pull$"
# features: "^punished$"
# features: "^push$"
# features: "^putting$"
# features: "^question$"
# features: "^questions$"
# features: "^quickly$"
# features: "^quite$"
# features: "^race$"
# features: "^reach$"
# features: "^read$"
# features: "^readers$"
# features: "^reading$"
# features: "^ready$"
# features: "^real$"
# features: "^reality$"
# features: "^realize$"
# features: "^realized$"
# features: "^really$"
# features: "^reason$"
# features: "^reasons$"
# features: "^reassured$"
# features: "^rebellious$"
# features: "^recently$"
# features: "^red$"
# features: "^regretful$"
# features: "^rejected$"
# features: "^relationship$"
# features: "^relaxed$"
# features: "^relieved$"
# features: "^reluctant$"
# features: "^rememb
# I0000 00:00:1733650922.571156    1741 kernel.cc:834] Deployment config:
# cache_path: "/tmp/tmpdwmsihg9/working_cache"
# num_threads: 2
# try_resume_training: true
#
# I0000 00:00:1733650922.571509    5761 kernel.cc:895] Train model
# I0000 00:00:1733650922.646971    5761 random_forest.cc:427] Training random forest on 333447 example(s) and 1000 feature(s).
# I0000 00:00:1733650956.528369    5761 preprocessing.cc:67] Feature index computed in 33.881353337s
# I0000 00:00:1733650960.722895    5899 random_forest.cc:811] Training of tree  1/300 (tree index:0) done accuracy:0.377201 logloss:22.448
# I0000 00:00:1733650971.639069    5899 random_forest.cc:811] Training of tree  5/300 (tree index:4) done accuracy:0.361153 logloss:21.2071
# I0000 00:00:1733650986.486279    5899 random_forest.cc:811] Training of tree  11/300 (tree index:10) done accuracy:0.355075 logloss:19.5879
# I0000 00:00:1733651001.329850    5899 random_forest.cc:811] Training of tree  17/300 (tree index:17) done accuracy:0.349356 logloss:18.189
# I0000 00:00:1733651016.126844    5899 random_forest.cc:811] Training of tree  23/300 (tree index:23) done accuracy:0.34635 logloss:17.1542
# I0000 00:00:1733651035.437166    5899 random_forest.cc:811] Training of tree  29/300 (tree index:28) done accuracy:0.344786 logloss:16.1869
# I0000 00:00:1733651046.441687    5900 random_forest.cc:811] Training of tree  32/300 (tree index:31) done accuracy:0.343749 logloss:15.8167
# I0000 00:00:1733651058.574597    5899 random_forest.cc:811] Training of tree  35/300 (tree index:34) done accuracy:0.343605 logloss:15.5874
# I0000 00:00:1733651069.004297    5900 random_forest.cc:811] Training of tree  40/300 (tree index:39) done accuracy:0.342888 logloss:15.2881
# I0000 00:00:1733651079.500344    5900 random_forest.cc:811] Training of tree  44/300 (tree index:43) done accuracy:0.34254 logloss:15.0403
# I0000 00:00:1733651089.835191    5900 random_forest.cc:811] Training of tree  48/300 (tree index:47) done accuracy:0.342216 logloss:14.7894
# I0000 00:00:1733651100.563545    5899 random_forest.cc:811] Training of tree  53/300 (tree index:52) done accuracy:0.342063 logloss:14.5783
# I0000 00:00:1733651111.751749    5899 random_forest.cc:811] Training of tree  57/300 (tree index:56) done accuracy:0.341664 logloss:14.4242
# I0000 00:00:1733651122.588251    5899 random_forest.cc:811] Training of tree  61/300 (tree index:60) done accuracy:0.341155 logloss:14.2942
# I0000 00:00:1733651132.940184    5900 random_forest.cc:811] Training of tree  66/300 (tree index:65) done accuracy:0.341308 logloss:14.0803
# I0000 00:00:1733651145.818511    5899 random_forest.cc:811] Training of tree  71/300 (tree index:70) done accuracy:0.341023 logloss:13.8644
# I0000 00:00:1733651156.135772    5899 random_forest.cc:811] Training of tree  75/300 (tree index:74) done accuracy:0.340477 logloss:13.6991
# I0000 00:00:1733651166.844969    5899 random_forest.cc:811] Training of tree  79/300 (tree index:78) done accuracy:0.340108 logloss:13.5849
# I0000 00:00:1733651177.096742    5900 random_forest.cc:811] Training of tree  84/300 (tree index:83) done accuracy:0.339601 logloss:13.442
# I0000 00:00:1733651187.100776    5900 random_forest.cc:811] Training of tree  88/300 (tree index:87) done accuracy:0.339565 logloss:13.3797
# I0000 00:00:1733651197.106535    5899 random_forest.cc:811] Training of tree  91/300 (tree index:90) done accuracy:0.339523 logloss:13.3203
# I0000 00:00:1733651211.648539    5899 random_forest.cc:811] Training of tree  97/300 (tree index:96) done accuracy:0.339325 logloss:13.0964
# I0000 00:00:1733651226.026563    5899 random_forest.cc:811] Training of tree  103/300 (tree index:102) done accuracy:0.339466 logloss:13.0417
# I0000 00:00:1733651240.495106    5899 random_forest.cc:811] Training of tree  109/300 (tree index:108) done accuracy:0.339373 logloss:12.7998
# I0000 00:00:1733651255.368782    5899 random_forest.cc:811] Training of tree  115/300 (tree index:114) done accuracy:0.339307 logloss:12.6598
# I0000 00:00:1733651265.786365    5900 random_forest.cc:811] Training of tree  120/300 (tree index:119) done accuracy:0.339244 logloss:12.535
# I0000 00:00:1733651276.743777    5900 random_forest.cc:811] Training of tree  124/300 (tree index:123) done accuracy:0.339289 logloss:12.4497
# I0000 00:00:1733651287.901169    5900 random_forest.cc:811] Training of tree  128/300 (tree index:127) done accuracy:0.339292 logloss:12.4023
# I0000 00:00:1733651299.536785    5899 random_forest.cc:811] Training of tree  133/300 (tree index:132) done accuracy:0.339232 logloss:12.3063
# I0000 00:00:1733651310.819068    5899 random_forest.cc:811] Training of tree  137/300 (tree index:136) done accuracy:0.339211 logloss:12.2694
# I0000 00:00:1733651321.634866    5899 random_forest.cc:811] Training of tree  141/300 (tree index:140) done accuracy:0.339157 logloss:12.1741
# I0000 00:00:1733651332.350103    5900 random_forest.cc:811] Training of tree  146/300 (tree index:145) done accuracy:0.339106 logloss:12.0991
# I0000 00:00:1733651346.310681    5899 random_forest.cc:811] Training of tree  151/300 (tree index:150) done accuracy:0.339139 logloss:11.9935
# I0000 00:00:1733651356.381477    5900 random_forest.cc:811] Training of tree  156/300 (tree index:155) done accuracy:0.339058 logloss:11.8069
# I0000 00:00:1733651367.257522    5900 random_forest.cc:811] Training of tree  160/300 (tree index:159) done accuracy:0.339049 logloss:11.7794
# I0000 00:00:1733651381.251726    5899 random_forest.cc:811] Training of tree  165/300 (tree index:164) done accuracy:0.339037 logloss:11.751
# I0000 00:00:1733651391.928516    5900 random_forest.cc:811] Training of tree  170/300 (tree index:169) done accuracy:0.339034 logloss:11.6207
# I0000 00:00:1733651404.320431    5899 random_forest.cc:811] Training of tree  175/300 (tree index:174) done accuracy:0.338995 logloss:11.5672
# I0000 00:00:1733651415.052141    5899 random_forest.cc:811] Training of tree  179/300 (tree index:178) done accuracy:0.338971 logloss:11.555
# I0000 00:00:1733651425.811708    5899 random_forest.cc:811] Training of tree  183/300 (tree index:182) done accuracy:0.338965 logloss:11.5146
# I0000 00:00:1733651436.819575    5900 random_forest.cc:811] Training of tree  188/300 (tree index:187) done accuracy:0.338938 logloss:11.4921
# I0000 00:00:1733651447.603330    5900 random_forest.cc:811] Training of tree  192/300 (tree index:191) done accuracy:0.338962 logloss:11.3862
# I0000 00:00:1733651458.105746    5900 random_forest.cc:811] Training of tree  196/300 (tree index:195) done accuracy:0.338926 logloss:11.2834
# I0000 00:00:1733651469.726654    5899 random_forest.cc:811] Training of tree  201/300 (tree index:200) done accuracy:0.338926 logloss:11.1284
# I0000 00:00:1733651480.744534    5900 random_forest.cc:811] Training of tree  206/300 (tree index:205) done accuracy:0.338935 logloss:11.1037
# I0000 00:00:1733651491.506796    5900 random_forest.cc:811] Training of tree  210/300 (tree index:209) done accuracy:0.338932 logloss:11.05
# I0000 00:00:1733651502.086646    5900 random_forest.cc:811] Training of tree  214/300 (tree index:213) done accuracy:0.338911 logloss:10.9911
# I0000 00:00:1733651516.710048    5900 random_forest.cc:811] Training of tree  220/300 (tree index:219) done accuracy:0.33892 logloss:10.8822
# I0000 00:00:1733651531.515499    5900 random_forest.cc:811] Training of tree  226/300 (tree index:225) done accuracy:0.338899 logloss:10.8156
# I0000 00:00:1733651546.658319    5900 random_forest.cc:811] Training of tree  232/300 (tree index:231) done accuracy:0.338896 logloss:10.7266
# I0000 00:00:1733651560.897199    5900 random_forest.cc:811] Training of tree  238/300 (tree index:237) done accuracy:0.338881 logloss:10.6464
# I0000 00:00:1733651575.818714    5900 random_forest.cc:811] Training of tree  244/300 (tree index:243) done accuracy:0.338845 logloss:10.6073
# I0000 00:00:1733651589.819298    5899 random_forest.cc:811] Training of tree  250/300 (tree index:250) done accuracy:0.338854 logloss:10.5991
# I0000 00:00:1733651603.418308    5900 random_forest.cc:811] Training of tree  256/300 (tree index:255) done accuracy:0.338866 logloss:10.5895
# I0000 00:00:1733651614.232208    5899 random_forest.cc:811] Training of tree  261/300 (tree index:260) done accuracy:0.338887 logloss:10.5837
# I0000 00:00:1733651624.705522    5899 random_forest.cc:811] Training of tree  265/300 (tree index:264) done accuracy:0.338866 logloss:10.5328
# I0000 00:00:1733651637.743524    5900 random_forest.cc:811] Training of tree  270/300 (tree index:269) done accuracy:0.338869 logloss:10.5067
# I0000 00:00:1733651642.158886    5900 random_forest.cc:590] Training interrupted per request
# I0000 00:00:1733651643.076814    5761 random_forest.cc:891] Final OOB metrics: accuracy:0.338869 logloss:10.5067
# I0000 00:00:1733651644.277280    5761 kernel.cc:926] Export model in log directory: /tmp/tmpdwmsihg9 with prefix 3fac71e036d64ff7
# I0000 00:00:1733651644.412102    5761 kernel.cc:944] Save model in resources
# I0000 00:00:1733651644.448356    1741 abstract_model.cc:914] Model self evaluation:
# Number of predictions (without weights): 333447
# Number of predictions (with weights): 333447
# Task: CLASSIFICATION
# Label: __LABEL
#
# Accuracy: 0.338869  CI95[W][0.337521 0.34022]
# LogLoss: : 10.5067
# ErrorRate: : 0.661131
#
# Default Accuracy: : 0.338345
# Default LogLoss: : 1.57336
# Default ErrorRate: : 0.661655
#
# Confusion Table:
# truth\prediction
#    1       2   3  4   5   6
# 1  0   96678   0  0   2   3
# 2  0  112814   0  0   4   2
# 3  0   27672  26  0   3   0
# 4  0   45957   0  3  17   1
# 5  0   38250   1  1  81   3
# 6  0   11825   0  0  33  71
# Total: 333447
#
#
# 2024-12-08 09:54:04.547524: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /tmp/tmpdwmsihg9/model/ with prefix 3fac71e036d64ff7
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733651644.853242    1741 decision_forest.cc:761] Model loaded with 273 root(s), 152767 node(s), and 989 input feature(s).
# I0000 00:00:1733651644.857339    1741 abstract_model.cc:1404] Engine "RandomForestGeneric" built
# 2024-12-08 09:54:04.858457: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# Model trained in 0:12:06.771858
# Compiling model...
# Model compiled.

# %% [markdown]
# # Evaluate Model

# %%
evaluation = model_1.evaluate(test_dataset, return_dict=True)
print()

for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 84/84 [==============================] - 86s 990ms/step - loss: 0.0000e+00 - accuracy: 0.3393
#
# loss: 0.0000
# accuracy: 0.3393
